# %%
# Step 1: Import Libraries and Load the Dataset
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#    accountAgeDays  numItems  localTime paymentMethod  paymentMethodAgeDays  \
# 0              29         1   4.745402        paypal             28.204861
# 1             725         1   4.742303   storecredit              0.000000
# 2             845         1   4.921318    creditcard              0.000000
# 3             503         1   4.886641    creditcard              0.000000
# 4            2000         1   5.040929    creditcard              0.000000
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39221 entries, 0 to 39220
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   accountAgeDays        39221 non-null  int64
#  1   numItems              39221 non-null  int64
#  2   localTime             39221 non-null  float64
#  3   paymentMethod         39221 non-null  object
#  4   paymentMethodAgeDays  39221 non-null  float64
#  5   label                 39221 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.8+ MB

# %%
#Detect missing values or NAN for an array-like object.
df.isnull().sum()
# Out:
# accountAgeDays          0
# numItems                0
# localTime               0
# paymentMethod           0
# paymentMethodAgeDays    0
# label                   0
# dtype: int64

# %%
# Load the data from the CSV file into a Pandas DataFrame and store it as 'df'
df.isnull().sum()
# Out:
# accountAgeDays          0
# numItems                0
# localTime               0
# paymentMethod           0
# paymentMethodAgeDays    0
# label                   0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         accountAgeDays      numItems     localTime paymentMethod  \
# count     39221.000000  39221.000000  39221.000000         39221
# unique             NaN           NaN           NaN             3
# top                NaN           NaN           NaN    creditcard
# freq               NaN           NaN           NaN         28004
# mean        857.563984      1.084751      4.748232           NaN
# std         804.788212      0.566899      0.389360           NaN
# min           1.000000      1.000000      0.421214           NaN
# 25%          72.000000      1.000000      4.742303           NaN
# 50%         603.000000      1.000000      4.886641           NaN
# 75%        1804.000000      1.000000      4.962055           NaN
# max        2000.000000     29.000000      5.040929           NaN
#
#         paymentMethodAgeDays         label
# count           39221.000000  39221.000000
# unique                   NaN           NaN
# top                      NaN           NaN
# ...

# %%
# Step 3: Convert Categorical Data
from sklearn.preprocessing import LabelEncoder

# Convert the string values in the 'paymentMethod' column into numeric values
label_encoder = LabelEncoder()
df['paymentMethod'] = label_encoder.fit_transform(df['paymentMethod'])
df
# Out:
#        accountAgeDays  numItems  localTime  paymentMethod  \
# 0                  29         1   4.745402              1
# 1                 725         1   4.742303              2
# 2                 845         1   4.921318              0
# 3                 503         1   4.886641              0
# 4                2000         1   5.040929              0
# ...               ...       ...        ...            ...
# 39216             986         1   4.836982              0
# 39217            1647         1   4.876771              0
# 39218            1591         1   4.742303              0
# 39219             237         1   4.921318              0
# 39220             272         1   5.040929              1
#
#        paymentMethodAgeDays  label
# 0                 28.204861      0
# 1                  0.000000      0
# 2                  0.000000      0
# 3                  0.000000      0
# 4                  0.000000      0
# ...                     ...    ...
# ...

# %%
from sklearn.model_selection import train_test_split

# Partitioning the dataset into distinct training and testing subsets
X = df.drop("label", axis=1)
y = df['label']

# %%
# We allocate 33% of the data for testing (evaluating our model), while the remaining 67% is designated for training (building our model).
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=17)

# %%
logistic_regression = LogisticRegression()
clf = logistic_regression.fit(X_train, y_train)

# Create predictions for the test data
y_pred = clf.predict(X_test)
print(accuracy_score(y_pred, y_test))
# Out:
# 1.0
# 1.0

# %%
# Assess how well the test predictions align with the true labels

# Evaluation
accuracy_linearR = accuracy_score(y_test, y_pred)
confusion_matrix_linearR = confusion_matrix(y_test, y_pred)

print("Accuracy : ", accuracy_linearR)
print("Confusion Matrix...\n", confusion_matrix_linearR)
# Out:
# Accuracy :  1.0
# Confusion Matrix...
#  [[12753     0]
#  [    0   190]]

# %%
# 3. Employing the Random Forest Algorithm

from sklearn.ensemble import RandomForestClassifier

# Establish a Random Forest Classifier model
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)

y_pred_rf = random_forest.predict(X_test)

accuracy_rf = accuracy_score(y_test, y_pred_rf)
confusion_matrix_rf = confusion_matrix(y_test, y_pred_rf)

print("Accuracy : ", accuracy_rf)
print("Confusion Matrix...\n", confusion_matrix_rf)
# Out:
# Accuracy :  1.0
# Confusion Matrix...
#  [[12753     0]
#  [    0   190]]
